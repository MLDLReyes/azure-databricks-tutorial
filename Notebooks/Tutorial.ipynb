# %% [markdown]
# # DATABRICKS MASTERCLASS

# %%
mydate = [(1,'aa',30),(2,'bb',40),(3,'cc',50)]

myschema = "id INT, name STRING, marks INT"

df = spark.createDataFrame(mydate,myschema)

# %%
df.display

# %% [markdown]
# ##Access Data

# %% [markdown]
# https://learn.microsoft.com/en-us/azure/databricks/connect/storage/tutorial-azure-storage

# %%
service_credential = dbutils.secrets.get(scope="datavault-secret-scope", key="service-credential")

spark.conf.set("fs.azure.account.auth.type.datalakemldlreyes.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.datalakemldlreyes.dfs.core.windows.net","org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.datalakemldlreyes.dfs.core.windows.net", "05f51d6d-2621-463f-8126-f10f8e235536")
spark.conf.set("fs.azure.account.oauth2.client.secret.datalakemldlreyes.dfs.core.windows.net", service_credential)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.datalakemldlreyes.dfs.core.windows.net","https://login.microsoftonline.com/5e52e3a6-ff9e-484f-87ce-df6111f764c8/oauth2/token")

# %% [markdown]
# ### DB Utilities

# %% [markdown]
# **dbutils.fs()**

# %%
dbutils.fs.ls("abfss://source@datalakemldlreyes.dfs.core.windows.net")

# %% [markdown]
# **dbutils.widgets**

# %%
dbutils.widgets.text("p_name", "luis")

# %%
var = dbutils.widgets.get("p_name")

# %%
var

# %% [markdown]
# **dbutils.secrets**

# %%
dbutils.secrets.list(scope="datavault-secret-scope")

# %%
dbutils.secrets.get(scope="datavault-secret-scope",key='service-credential')

# %% [markdown]
# # Data Reading

# %%
df_sales = spark.read.format('csv')\
                .option('header',True)\
                .option('inferSchema',True)\
                .load('abfss://source@datalakemldlreyes.dfs.core.windows.net/sales.csv')

# %%
df_sales.display()

# %% [markdown]
# ### PySpark Transformations

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_sales.withColumn('Item_Type',split(col('Item_Type'),' ')).display()

# %%
df_sales.withColumn('flag',lit(var)).display()

# %%
df_sales.withColumn('Item_Visibility',col('Item_Visibility').cast(StringType())).display()
